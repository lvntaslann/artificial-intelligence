# %%
import matplotlib.pyplot as plt

# %%
#x=[1,2,3,4,5,6,7]
x=range(1,8)
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='black',linewidth=5,linestyle='-')

# %%
plt.xlabel('Haftanın günleri')
plt.ylabel('Sıcaklık(derece)')
plt.title('Sıcaklığın günlere göre dağılımı')
plt.plot(x,y,color="green",linewidth=5,linestyle='dashdot')

# %%
plt.plot(x,y,':+m')

# %%
plt.plot(x,y,'k3-.')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='--')

# %%
plt.plot(x,y,color='#206890',marker='+',linestyle='--',markersize=10)

# %%
plt.plot(x,y,color='#313131',marker='+',linestyle='--',alpha=0.6)

# %%
import random
days=range(1,8)
max_t=np.random.randint(50,60,size=7)
min_t=np.random.randint(25,40,size=7)
avg_t=np.random.randint(40,50,size=7)

# %%
plt.plot(days,max_t)

# %%
plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)

# %%
plt.xlabel('Haftanın günleri')
plt.ylabel('Sıcaklık(derece)')
plt.title('Sıcaklık analizi')
plt.plot(days,max_t,label='max-sıcaklık')
plt.plot(days,min_t,label='min-sıcaklık')
plt.plot(days,avg_t,label='avg-sıcaklık')

plt.legend()
# plt.legend(loc='best') or plt.legend(loc='upper right')
