# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptop_prices.csv')
df.head()
# Out:
#     Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0   Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1   Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2    Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3  Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4   Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
#
#    Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# 0                17.3  2560x1440                   8.9         1.42
# 1                14.0   1366x768                   9.4         2.57
# 2                13.3  3840x2160                   8.5         1.74
# 3                13.3   1366x768                  10.5         3.10
# 4                16.0  3840x2160                   5.7         3.38
#
#   Operating System  Price ($)
# 0          FreeDOS    3997.07
# 1            Linux    1355.78
# 2          FreeDOS    2673.07
# 3          Windows     751.17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11768 entries, 0 to 11767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 11768 non-null  object
#  1   Processor             11768 non-null  object
#  2   RAM (GB)              11768 non-null  int64
#  3   Storage               11768 non-null  object
#  4   GPU                   11768 non-null  object
#  5   Screen Size (inch)    11768 non-null  float64
#  6   Resolution            11768 non-null  object
#  7   Battery Life (hours)  11768 non-null  float64
#  8   Weight (kg)           11768 non-null  float64
#  9   Operating System      11768 non-null  object
#  10  Price ($)             11768 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1011.4+ KB

# %%
df.columns
# Out:
# Index(['Brand', 'Processor', 'RAM (GB)', 'Storage', 'GPU',
#        'Screen Size (inch)', 'Resolution', 'Battery Life (hours)',
#        'Weight (kg)', 'Operating System', 'Price ($)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Brand                   0
# Processor               0
# RAM (GB)                0
# Storage                 0
# GPU                     0
# Screen Size (inch)      0
# Resolution              0
# Battery Life (hours)    0
# Weight (kg)             0
# Operating System        0
# Price ($)               0
# dtype: int64

# %%
filtered_df = df[
    (df['Brand'] == 'Apple') & 
    (
        (df['Processor'] == 'AMD Ryzen 3') |
        (df['Processor'] == 'AMD Ryzen 5') |
        (df['Processor'] == 'AMD Ryzen 7')
    )
]

group_df = filtered_df.groupby(['Brand', 'Processor'])
group_df.head()
# Out:
#      Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0    Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 95   Apple  AMD Ryzen 3        32    2TB SSD     Nvidia RTX 3080
# 167  Apple  AMD Ryzen 5        16  256GB SSD     Nvidia RTX 3080
# 168  Apple  AMD Ryzen 3        16    1TB SSD          Integrated
# 179  Apple  AMD Ryzen 3         4    2TB SSD     Nvidia RTX 3060
# 241  Apple  AMD Ryzen 7        32    2TB SSD          Integrated
# 336  Apple  AMD Ryzen 7        16    1TB SSD     Nvidia RTX 3060
# 356  Apple  AMD Ryzen 3         4    1TB SSD     Nvidia RTX 3080
# 360  Apple  AMD Ryzen 5        16    2TB SSD  AMD Radeon RX 6600
# 385  Apple  AMD Ryzen 7        64  512GB SSD  AMD Radeon RX 6800
# 399  Apple  AMD Ryzen 5         8    2TB SSD          Integrated
# 442  Apple  AMD Ryzen 7        32  512GB SSD     Nvidia RTX 3080
# 460  Apple  AMD Ryzen 7         8  256GB SSD  AMD Radeon RX 6600
# ...

# %%
from sklearn.preprocessing import LabelEncoder

brand_encoder = LabelEncoder()
processor_encoder = LabelEncoder()
gpu_encoder = LabelEncoder()
resolution_encoder = LabelEncoder()
os_encoder = LabelEncoder()

df['Brand'] = brand_encoder.fit_transform(df['Brand'])
df['Processor'] = processor_encoder.fit_transform(df['Processor'])
df['GPU'] = gpu_encoder.fit_transform(df['GPU'])
df['Resolution'] = resolution_encoder.fit_transform(df['Resolution'])
df['Operating System'] = os_encoder.fit_transform(df['Operating System'])
df.head()
# Out:
#    Brand  Processor  RAM (GB)    Storage  GPU  Screen Size (inch)  Resolution  \
# 0      1          0        64  512GB SSD    3                17.3           2
# 1      8          2         4    1TB SSD    6                14.0           0
# 2      2          5        32    2TB SSD    5                13.3           3
# 3      5          5         4  256GB SSD    6                13.3           0
# 4      8          4         4  256GB SSD    0                16.0           3
#
#    Battery Life (hours)  Weight (kg)  Operating System  Price ($)
# 0                   8.9         1.42                 0    3997.07
# 1                   9.4         2.57                 1    1355.78
# 2                   8.5         1.74                 0    2673.07
# 3                  10.5         3.10                 2     751.17
# 4                   5.7         3.38                 1    2059.83

# %%
df['Storage'].value_counts()
# Out:
# Storage
# 512GB SSD    2420
# 2TB SSD      2415
# 256GB SSD    2318
# 1TB SSD      2313
# 1TB HDD      2302
# Name: count, dtype: int64

# %%
storage_encoder = LabelEncoder()
df['Storage'] = storage_encoder.fit_transform(df['Storage'])
df.head()
# Out:
#    Brand  Processor  RAM (GB)  Storage  GPU  Screen Size (inch)  Resolution  \
# 0      1          0        64        4    3                17.3           2
# 1      8          2         4        1    6                14.0           0
# 2      2          5        32        3    5                13.3           3
# 3      5          5         4        2    6                13.3           0
# 4      8          4         4        2    0                16.0           3
#
#    Battery Life (hours)  Weight (kg)  Operating System  Price ($)
# 0                   8.9         1.42                 0    3997.07
# 1                   9.4         2.57                 1    1355.78
# 2                   8.5         1.74                 0    2673.07
# 3                  10.5         3.10                 2     751.17
# 4                   5.7         3.38                 1    2059.83

# %%
df.describe()
# Out:
#               Brand     Processor      RAM (GB)       Storage           GPU  \
# count  11768.000000  11768.000000  11768.000000  11768.000000  11768.000000
# mean       4.460486      3.511982     24.852821      2.028722      3.002209
# std        2.869467      2.289424     21.762567      1.416384      1.992122
# min        0.000000      0.000000      4.000000      0.000000      0.000000
# 25%        2.000000      2.000000      8.000000      1.000000      1.000000
# 50%        4.000000      4.000000     16.000000      2.000000      3.000000
# 75%        7.000000      6.000000     32.000000      3.000000      5.000000
# max        9.000000      7.000000     64.000000      4.000000      6.000000
#
#        Screen Size (inch)    Resolution  Battery Life (hours)   Weight (kg)  \
# count        11768.000000  11768.000000          11768.000000  11768.000000
# mean            15.212305      1.505693              8.027855      2.341117
# ...

# %%
df.info()
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11768 entries, 0 to 11767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 11768 non-null  int32
#  1   Processor             11768 non-null  int32
#  2   RAM (GB)              11768 non-null  int64
#  3   Storage               11768 non-null  int32
#  4   GPU                   11768 non-null  int32
#  5   Screen Size (inch)    11768 non-null  float64
#  6   Resolution            11768 non-null  int32
#  7   Battery Life (hours)  11768 non-null  float64
#  8   Weight (kg)           11768 non-null  float64
#  9   Operating System      11768 non-null  int32
#  10  Price ($)             11768 non-null  float64
# dtypes: float64(4), int32(6), int64(1)
# memory usage: 735.6 KB
# Brand                     int32
# Processor                 int32
# RAM (GB)                  int64
# Storage                   int32
# ...

# %%
df = df.rename(columns={'Brand': 'marka',
                        'Processor': 'islemci',
                        'RAM(GB)': 'ram',
                        'Storage': 'depolama',
                        'Screen Size (inch)': 'ekranboyutu',
                        'Resolution': 'cozunurluk',
                        'Battery Life (hours)': 'saatlik_batarya_omru',
                        'Weight (kg)': 'agirlik',
                        'Operating System':'isletim_sistemi',
                        'Price ($)':'fiyat'})

df.head()
# Out:
#    marka  islemci  RAM (GB)  depolama  GPU  ekranboyutu  cozunurluk  \
# 0      1        0        64         4    3         17.3           2
# 1      8        2         4         1    6         14.0           0
# 2      2        5        32         3    5         13.3           3
# 3      5        5         4         2    6         13.3           0
# 4      8        4         4         2    0         16.0           3
#
#    saatlik_batarya_omru  agirlik  isletim_sistemi    fiyat
# 0                   8.9     1.42                0  3997.07
# 1                   9.4     2.57                1  1355.78
# 2                   8.5     1.74                0  2673.07
# 3                  10.5     3.10                2   751.17
# 4                   5.7     3.38                1  2059.83

# %%
x = df.drop('fiyat',axis=1)
y = df['fiyat']
x=x.values.astype('float64')
y=y.values.astype('float64')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.80,random_state = 42)
print(x_train.shape)
print(y_train.shape)
# Out:
# (9414, 10)
# (9414,)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='relu'))

model.compile(optimizer="adam",loss='mse',metrics=["mae"])

# %%
model.fit(x_train,y_train,epochs=256,batch_size=32)
# Out:
# Epoch 1/256
# 295/295 [==============================] - 1s 3ms/step - loss: 107028.2422 - mae: 229.3518
# Epoch 2/256
# 295/295 [==============================] - 1s 2ms/step - loss: 109243.9609 - mae: 233.1398
# Epoch 3/256
# 295/295 [==============================] - 1s 2ms/step - loss: 105687.4375 - mae: 228.9635
# Epoch 4/256
# 295/295 [==============================] - 1s 2ms/step - loss: 106096.6797 - mae: 227.9079
# Epoch 5/256
# 295/295 [==============================] - 1s 2ms/step - loss: 99570.4531 - mae: 222.4032
# Epoch 6/256
# 295/295 [==============================] - 1s 2ms/step - loss: 105655.0781 - mae: 226.6413
# Epoch 7/256
# 295/295 [==============================] - 1s 2ms/step - loss: 103021.4141 - mae: 225.8001
# Epoch 8/256
# 295/295 [==============================] - 1s 2ms/step - loss: 118592.8281 - mae: 238.7834
# Epoch 9/256
# 295/295 [==============================] - 1s 2ms/step - loss: 97709.8516 - mae: 219.2370
# Epoch 10/256
# ...

# %%
df.head()
# Out:
#    marka  islemci  RAM (GB)  depolama  GPU  ekranboyutu  cozunurluk  \
# 0      1        0        64         4    3         17.3           2
# 1      8        2         4         1    6         14.0           0
# 2      2        5        32         3    5         13.3           3
# 3      5        5         4         2    6         13.3           0
# 4      8        4         4         2    0         16.0           3
#
#    saatlik_batarya_omru  agirlik  isletim_sistemi    fiyat
# 0                   8.9     1.42                0  3997.07
# 1                   9.4     2.57                1  1355.78
# 2                   8.5     1.74                0  2673.07
# 3                  10.5     3.10                2   751.17
# 4                   5.7     3.38                1  2059.83

# %%
tahmin = model.predict(np.expand_dims(x_test[0], axis=0))
# Out:
# 1/1 [==============================] - 0s 84ms/step

# %%
print(tahmin)
# Out:
# [[1109.2045]]

# %%
y_test[0]
# Out:
# 1240.54

# %%
# Asus	Intel i5	32	2TB SSD	Nvidia RTX 3060	13.3	3840x2160	8.5	1.74	FreeDOS	2673.07
# verisetindeki 1.satır
tahmin2 = model.predict(np.array([[8,2,4,1,6,14.0,0,9.4,2.57,1]]))
print(tahmin2)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [[1275.9467]]

# %%
print("Label Encoded Brands:", brand_encoder.classes_)
print("Label Encoded Processors:", processor_encoder.classes_)
print("Label Encoded GPUs:", gpu_encoder.classes_)
print("Label Encoded Resolutions:", resolution_encoder.classes_)
print("Label Encoded OS:", os_encoder.classes_)
print("Label Encoded Storage:", storage_encoder.classes_)
# Out:
# Label Encoded Brands: ['Acer' 'Apple' 'Asus' 'Dell' 'HP' 'Lenovo' 'MSI' 'Microsoft' 'Razer'
#  'Samsung']
# Label Encoded Processors: ['AMD Ryzen 3' 'AMD Ryzen 5' 'AMD Ryzen 7' 'AMD Ryzen 9' 'Intel i3'
#  'Intel i5' 'Intel i7' 'Intel i9']
# Label Encoded GPUs: ['AMD Radeon RX 6600' 'AMD Radeon RX 6800' 'Integrated' 'Nvidia GTX 1650'
#  'Nvidia RTX 2060' 'Nvidia RTX 3060' 'Nvidia RTX 3080']
# Label Encoded Resolutions: ['1366x768' '1920x1080' '2560x1440' '3840x2160']
# Label Encoded OS: ['FreeDOS' 'Linux' 'Windows' 'macOS']
# Label Encoded Storage: ['1TB HDD' '1TB SSD' '256GB SSD' '2TB SSD' '512GB SSD']

# %%
df.head()
# Out:
#    marka  islemci  RAM (GB)  depolama  GPU  ekranboyutu  cozunurluk  \
# 0      1        0        64         4    3         17.3           2
# 1      8        2         4         1    6         14.0           0
# 2      2        5        32         3    5         13.3           3
# 3      5        5         4         2    6         13.3           0
# 4      8        4         4         2    0         16.0           3
#
#    saatlik_batarya_omru  agirlik  isletim_sistemi    fiyat
# 0                   8.9     1.42                0  3997.07
# 1                   9.4     2.57                1  1355.78
# 2                   8.5     1.74                0  2673.07
# 3                  10.5     3.10                2   751.17
# 4                   5.7     3.38                1  2059.83

# %%
# dell,inteli7,32gbram,1tb ssd,3060,17.3,1920x1080,10.2batarya,3.5kg,freedos
tahmin3 = model.predict(np.array([[3,6,32,1,5,17.3,1,10.2,3.5,0]]))
print(tahmin3)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [[2279.6074]]
